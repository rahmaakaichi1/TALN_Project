# %% [markdown]
# # Identification automatique des collocations

# %% [markdown]
# ### **Collocations : a sequence of 2 or more words that appears to be together and not put randomly .**

# %% [markdown]
# ### Interest: Automatic translation , information search , part of speech **tagging**

# %% [markdown]
# # **Importing the corpus**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import nltk
import os

# %%
# !unzip  '/content/drive/My Drive/TALN_Project/Corpus-PADT-txt.zip' -d '/content/drive/My Drive/TALN_Project'

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
#set(stopwords.words('arabic'))
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
#with ntlk
'''from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
import unicodedata as ud

def remove_stop_words(f):
  data = ""
  punct =",;!?<>"
  stop_words = set(stopwords.words('arabic')) 
  with open(f, 'r') as f:
    data = f.readlines()
    
 
    tokens = word_tokenize("".join(data)) 
    filtered = [w for w in tokens if not w in stop_words] 
    
    filtered = [w for w in tokens if w not in PUNCTUATION_MARKS]
    return " ".join(filtered)
    #return filtered
'''

# %%
# !pip install cltk
from cltk.corpus.arabic.alphabet import *

# %%
dir = '/content/drive/My Drive/TALN_Project'

# %%
#removing stopwords using cltk
from cltk.stop.arabic.stopword_filter import stopwords_filter as ar_stop_filter
def remove_stop_wordss(f):
  data = ""
 
  with open(f, 'r') as f:
    data = f.readlines()
    print(data)
    
    return "".join(data)
    #return ar_stop_filter(data)

# %%
result = remove_stop_wordss('/content/drive/My Drive/TALN_Project/Corpus-PADT-txt/ALH20010911.0001_story.txt')
# Out:
# ['\n', 'فؤاد كنعان، رائد القصة القصيرة في لبنان رحل مساء أمس عن 81 عاماً.\n', '\n', 'أستاذ من أساتذة النثر العربي المضيء، المشبع بالجمالية والأناقة اللفظية والعمق الوجودي. قاص كان له أثره الكبير في تأسيس الشكل الجديد للقصة القصيرة في لبنان، وقبل ان يجدد في حقل الفن القصصي كان خير وارث لجيل النهضويين، لغة وأدباً.\n', '\n', 'كتابه القصصي الأول الذي صدر في العام 1947 وضع مقدمته »شيخ الأدباء« مارون عبود، وكانت بمثابة المقدمة الوحيدة التي لم يكتب مارون عبود سواها لأي كتاب، أياً كان صاحبه.\n', '\n', 'ولعل شغف فؤاد كنعان اللغوي ونزعته الى الاناقة في التعبير، والمتانة في السبك، جعلاه من الكتّاب المقلين، الذين يرفضون الاطناب والافاضة، وكان يؤثر التمهل في الكتابة متخيراً ألفاظه بدقة وجمالية، وصائغاً جمله صوغ الأساتذة الماهرين. مجموعته القصصية »أولاً وآخراً وبين بين« كانت أشبه بالحدث القصصي عندما صدرت في العام 1974. وعرفت تلك القصص بجرأة نادرة راح الكاتب يواجه من خلالها موضوعات كانت شائكة ولا تزال كالجنس والخيانة.\n', '\n', 'وله في حقل الترجمة أعمال عدة من أبرزها رواية الكاتب الفرنسي بلزاك »أوج
# ...

# %%
#this one
def remove_punct():
  corpus=[]
  forbidden ="\\.|,|:|;|!|_|،|؛|؟\\?»«"
  #ar_stop_filter arg is text
  sen = " ".join(ar_stop_filter(result)).split(',')
  
  for s in sen:
      print(s)
      l = s.split()
      print(l)
      lis = []
      for word in l:
          if word not in forbidden and  word != "\n" and word != "..." and  word.isalpha():
                sen = "".join(word)
                lis.append(sen)
  corpus = lis
  return corpus

# %%
corpus = remove_punct()
# Out:
#  يصر الفنان أحمد السنباطي نجل الموسيقار الكبير رياض السنباطي مناشدة المطربة فيروز إصدار الأغنيات الثلاث كان لحنها والده العام 1980 . فيروز تملك حقوق الأغنيات كاملة تصر بدورها التكتم شأنها وكأنها حال الحيرة تستطع طوال عشرين عاما تتخطاها » تحسمها «. ترى لماذا تتردد السيدة فيروز إصدار الأغنيات النادرة ولماذا تزداد تكتما عليها ؟
#
#  عام أعلن أحمد السنباطي لـ » الحياة « أنه سيصدر التسجيل يضم لقاء رياض السنباطي وفيروز يؤديان معا يشبه » التمرين « أغنية » بيني وبينك «. اللقاء كان الأول الموسيقار الكبير و » شاعرة الصوت « مطلع صيف 1980 واكتشف السنباطي خلاله قرب » طبقات عالية جدا « كانت زالت مخنوقة صوت فيروز عبر حينذاك لقاء صحافي عاصف . أحمد السنباطي ( الابن )، توعد المطربة فيروز بإصدار التسجيل بدءا اليوم ( الذكرى العشرين لرحيل والده ) ردا تكتمها شأن الأغنيات الثلاث ، فاته ان التسجيل بات حوزة الكثيرين ، لبنانيين ومصريين . أصلا صالح للنشر أنه مجرد تسجيل لجلسة تمرين ، تكمن قيمته طابعه » الوثائقي «، خصوصا المطربة سجلت الأغنية نفسها مرتين وفي صيغة نهائية بديعة وتوزيع موسيقي جميل .
#
# ...

# %%
files  = os.listdir('/content/drive/My Drive/TALN_Project/Corpus-PADT-txt')[:2]
files
# Out:
# ['ALH20010911.0001_story.txt', 'ALH20010911.0002_story.txt']

# %%
for f in files :
  print(os.path.join('/content/drive/My Drive/TALN_Project/Corpus-PADT-txt',f))
# Out:
# /content/drive/My Drive/TALN_Project/Corpus-PADT-txt/ALH20010911.0001_story.txt
# /content/drive/My Drive/TALN_Project/Corpus-PADT-txt/ALH20010911.0002_story.txt

# %%
/content/drive/My Drive/TALN_Project/Corpus-PADT-txt/ALH20010911.0001_story.txt

# %%
#for all documents:
all = []
for f in files:
  path = os.path.join('/content/drive/My Drive/TALN_Project/Corpus-PADT-txt',f)
  result = remove_stop_wordss(path)
  corpus = remove_punct()
  print(corpus)
  all.append(corpus)
# Out:
# ['\n', 'فؤاد كنعان، رائد القصة القصيرة في لبنان رحل مساء أمس عن 81 عاماً.\n', '\n', 'أستاذ من أساتذة النثر العربي المضيء، المشبع بالجمالية والأناقة اللفظية والعمق الوجودي. قاص كان له أثره الكبير في تأسيس الشكل الجديد للقصة القصيرة في لبنان، وقبل ان يجدد في حقل الفن القصصي كان خير وارث لجيل النهضويين، لغة وأدباً.\n', '\n', 'كتابه القصصي الأول الذي صدر في العام 1947 وضع مقدمته »شيخ الأدباء« مارون عبود، وكانت بمثابة المقدمة الوحيدة التي لم يكتب مارون عبود سواها لأي كتاب، أياً كان صاحبه.\n', '\n', 'ولعل شغف فؤاد كنعان اللغوي ونزعته الى الاناقة في التعبير، والمتانة في السبك، جعلاه من الكتّاب المقلين، الذين يرفضون الاطناب والافاضة، وكان يؤثر التمهل في الكتابة متخيراً ألفاظه بدقة وجمالية، وصائغاً جمله صوغ الأساتذة الماهرين. مجموعته القصصية »أولاً وآخراً وبين بين« كانت أشبه بالحدث القصصي عندما صدرت في العام 1974. وعرفت تلك القصص بجرأة نادرة راح الكاتب يواجه من خلالها موضوعات كانت شائكة ولا تزال كالجنس والخيانة.\n', '\n', 'وله في حقل الترجمة أعمال عدة من أبرزها رواية الكاتب الفرنسي بلزاك »أوج
# ...

# %%
all
# Out:
# [['فؤاد',
#   'كنعان',
#   'رائد',
#   'القصة',
#   'القصيرة',
#   'لبنان',
#   'رحل',
#   'مساء',
#   'أمس',
#   'عاما',
#   'أستاذ',
#   'أساتذة',
#   'النثر',
#   'العربي',
#   'المضيء',
#   'المشبع',
#   'بالجمالية',
#   'والأناقة',
#   'اللفظية',
#   'والعمق',
#   'الوجودي',
#   'قاص',
#   'كان',
#   'أثره',
#   'الكبير',
#   'تأسيس',
#   'الشكل',
#   'الجديد',
#   'للقصة',
#   'القصيرة',
#   'لبنان',
#   'وقبل',
#   'ان',
#   'يجدد',
#   'حقل',
#   'الفن',
#   'القصصي',
#   'كان',
#   'خير',
#   'وارث',
#   'لجيل',
#   'النهضويين',
#   'لغة',
#   'وأدبا',
#   'كتابه',
#   'القصصي',
#   'الأول',
#   'صدر',
#   'العام',
#   'وضع',
#   'مقدمته',
#   'شيخ',
#   'الأدباء',
#   'مارون',
#   'عبود',
#   'وكانت',
#   'بمثابة',
#   'المقدمة',
#   'الوحيدة',
#   'يكتب',
#   'مارون',
#   'عبود',
#   'سواها',
#   'لأي',
#   'كتاب',
#   'أيا',
#   'كان',
#   'صاحبه',
#   'ولعل',
#   'شغف',
#   'فؤاد',
#   'كنعان',
#   'اللغوي',
#   'ونزعته',
#   'الى',
#   'الاناقة',
#   'التعبير',
# ...

# %%
print(len(all))
# Out:
# 2

# %% [markdown]
# # Word2Vec

# %%
corpus # for one dct
# Out:
# ['يصر',
#  'الفنان',
#  'أحمد',
#  'السنباطي',
#  'نجل',
#  'الموسيقار',
#  'الكبير',
#  'رياض',
#  'السنباطي',
#  'مناشدة',
#  'المطربة',
#  'فيروز',
#  'إصدار',
#  'الأغنيات',
#  'الثلاث',
#  'كان',
#  'لحنها',
#  'والده',
#  'العام',
#  'فيروز',
#  'تملك',
#  'حقوق',
#  'الأغنيات',
#  'كاملة',
#  'تصر',
#  'بدورها',
#  'التكتم',
#  'شأنها',
#  'وكأنها',
#  'حال',
#  'الحيرة',
#  'تستطع',
#  'طوال',
#  'عشرين',
#  'عاما',
#  'تتخطاها',
#  'تحسمها',
#  'ترى',
#  'لماذا',
#  'تتردد',
#  'السيدة',
#  'فيروز',
#  'إصدار',
#  'الأغنيات',
#  'النادرة',
#  'ولماذا',
#  'تزداد',
#  'تكتما',
#  'عليها',
#  'عام',
#  'أعلن',
#  'أحمد',
#  'السنباطي',
#  'لـ',
#  'الحياة',
#  'أنه',
#  'سيصدر',
#  'التسجيل',
#  'يضم',
#  'لقاء',
#  'رياض',
#  'السنباطي',
#  'وفيروز',
#  'يؤديان',
#  'معا',
#  'يشبه',
#  'التمرين',
#  'أغنية',
#  'بيني',
#  'وبينك',
#  'اللقاء',
#  'كان',
#  'الأول',
#  'الموسيقار',
#  'الكبير',
#  'و',
#  'شاعرة',
#  'الصوت',
#  'مطلع',
#  'صيف',
#  'واكتشف',
#  'السنباطي',
# ...

# %%
len(corpus) # [[dct1 splitted in words] , [dct2 splitted in words]]
# Out:
# 1

# %%
from gensim.models.word2vec import Word2Vec
from multiprocessing import cpu_count
import gensim.downloader as api

# 

# Split the data into 2 parts. Part 2 will be used later to update the model
#data_part1 = cor[:10]
d#ata_part2 = cor[10:]

# Train Word2Vec model. Defaults result vector size = 100
#model = Word2Vec(data_part1, min_count = 0, workers=cpu_count())
model = Word2Vec(corpus, min_count = 0, workers=cpu_count())

# %%
# Get the word vector for given word
model['مجلة']
#> array([ 0.0512,  0.2555,  0.9393, ... ,-0.5669,  0.6737], dtype=float32)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([ 0.00277122,  0.002522  , -0.00010955, -0.00090123, -0.00120091,
#        -0.00197817, -0.00383522, -0.00315044,  0.00194398, -0.00335891,
#         0.00400244,  0.00148339,  0.00056845,  0.00024262, -0.00365311,
#        -0.00243339, -0.00294009,  0.00241188, -0.00085552, -0.00151691,
#        -0.00219661,  0.00323026,  0.00129415, -0.00052684, -0.00271819,
#        -0.00472894, -0.00291239,  0.00052104, -0.00453564, -0.00016294,
#         0.00111477,  0.0022121 ,  0.00291683, -0.00472278,  0.00132339,
#         0.00159994, -0.00289969,  0.00106989, -0.00268991,  0.00057326,
#         0.00023237, -0.00341247,  0.00459199, -0.00445385,  0.00020181,
#         0.00233489, -0.00386686, -0.00259987, -0.00246815, -0.00204319,
# ...

# %%
model.most_similar('مجلة')
#> [('discussion', 0.7590423822402954),
#>  ('consensus', 0.7253159284591675),
#>  ('discussions', 0.7252693176269531),
#>  ('interpretation', 0.7196053266525269),
#>  ('viewpoint', 0.7053568959236145),
#>  ('speculation', 0.7021505832672119),
#>  ('discourse', 0.7001898884773254),
#>  ('opinions', 0.6993060111999512),
#>  ('focus', 0.6959210634231567),
#>  ('scholarly', 0.6884037256240845)]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('جعلاه', 0.27173182368278503),
#  ('ينفتح', 0.22807662189006805),
#  ('ونزعته', 0.21118244528770447),
#  ('الحاج', 0.20970799028873444),
#  ('النهضويين', 0.20029108226299286),
#  ('عدة', 0.19792868196964264),
#  ('أدونيس', 0.18245331943035126),
#  ('قاص', 0.1800071895122528),
#  ('استطاع', 0.17296193540096283),
#  ('عندما', 0.17142827808856964)]

# %%
# Save and Load Model
model.save(os.path.join('/content/drive/My Drive/TALN_Project','newmodel'))
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %% [markdown]
# # **for all dcts**

# %%
all
# Out:
# [['فؤاد',
#   'كنعان',
#   'رائد',
#   'القصة',
#   'القصيرة',
#   'لبنان',
#   'رحل',
#   'مساء',
#   'أمس',
#   'عاما',
#   'أستاذ',
#   'أساتذة',
#   'النثر',
#   'العربي',
#   'المضيء',
#   'المشبع',
#   'بالجمالية',
#   'والأناقة',
#   'اللفظية',
#   'والعمق',
#   'الوجودي',
#   'قاص',
#   'كان',
#   'أثره',
#   'الكبير',
#   'تأسيس',
#   'الشكل',
#   'الجديد',
#   'للقصة',
#   'القصيرة',
#   'لبنان',
#   'وقبل',
#   'ان',
#   'يجدد',
#   'حقل',
#   'الفن',
#   'القصصي',
#   'كان',
#   'خير',
#   'وارث',
#   'لجيل',
#   'النهضويين',
#   'لغة',
#   'وأدبا',
#   'كتابه',
#   'القصصي',
#   'الأول',
#   'صدر',
#   'العام',
#   'وضع',
#   'مقدمته',
#   'شيخ',
#   'الأدباء',
#   'مارون',
#   'عبود',
#   'وكانت',
#   'بمثابة',
#   'المقدمة',
#   'الوحيدة',
#   'يكتب',
#   'مارون',
#   'عبود',
#   'سواها',
#   'لأي',
#   'كتاب',
#   'أيا',
#   'كان',
#   'صاحبه',
#   'ولعل',
#   'شغف',
#   'فؤاد',
#   'كنعان',
#   'اللغوي',
#   'ونزعته',
#   'الى',
#   'الاناقة',
#   'التعبير',
# ...

# %%
print(len(all))
# Out:
# 2

# %%
# for all dct
from gensim.models.word2vec import Word2Vec
from multiprocessing import cpu_count
import gensim.downloader as api

# 

# Split the data into 2 parts. Part 2 will be used later to update the model
#data_part1 = all[:10]
d#ata_part2 = cor[10:]

# Train Word2Vec model. Defaults result vector size = 100
#model = Word2Vec(data_part1, min_count = 0, workers=cpu_count())
model1 = Word2Vec(all, min_count = 0, workers=cpu_count())

# %%
# Get the word vector for given word
model1['فريد']
#> array([ 0.0512,  0.2555,  0.9393, ... ,-0.5669,  0.6737], dtype=float32)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([-4.7442447e-03, -3.6261615e-03, -2.9435891e-03,  3.4708560e-03,
#         4.1517676e-03,  2.4092256e-03,  2.1239626e-03, -4.9601938e-03,
#        -3.9942544e-03,  1.0760574e-03,  1.4776899e-03, -1.0742551e-03,
#        -4.5526833e-03, -4.9821273e-03,  4.4787312e-03,  1.4238161e-03,
#         1.7456961e-03, -3.4279637e-03, -4.8562395e-03, -2.8420985e-03,
#         2.3224354e-03,  2.3636778e-04, -4.7054691e-03,  4.4192411e-03,
#        -2.1752394e-03, -3.6810674e-03, -1.2217143e-03,  1.2382799e-03,
#         1.8766623e-03, -2.0135019e-03, -1.7972909e-03,  3.6647078e-03,
#        -8.8409637e-04, -1.8289465e-03, -2.6806889e-03, -1.8245417e-03,
#         4.2624245e-03, -3.1706549e-03,  4.8995391e-03,  3.9980733e-03,
# ...

# %%
model1.most_similar('موسيقي')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('موضوعات', 0.3008396029472351),
#  ('وآخرا', 0.29128989577293396),
#  ('والأجواء', 0.27179259061813354),
#  ('أليم', 0.26277124881744385),
#  ('ألحانه', 0.25735342502593994),
#  ('سرعة', 0.2355382740497589),
#  ('الخال', 0.2300380915403366),
#  ('مائلا', 0.22074399888515472),
#  ('لبى', 0.21804074943065643),
#  ('يسير', 0.2165902853012085)]

# %% [markdown]
# # **Visualize Embedding with matplotlib**

# %%
from sklearn.manifold import TSNE
import numpy as np 
import matplotlib.pyplot as plt

# %%
# fit a 2d PCA model to the vectors
from sklearn.decomposition import PCA #Grab PCA functions

X = model1[model1.wv.vocab]
pca = PCA(n_components=2)
result = pca.fit_transform(X)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# create a plot of the projection
fig, ax = plt.subplots()
ax.plot(result[:, 0], result[:, 1], 'o')
ax.set_title('Vocab')
plt.show()

# %% [markdown]
# # **visuaalize with t-SNE**

# %%
# !pip install tsne
# Out:
# ...
#   Created wheel for tsne: filename=tsne-0.1.8-cp36-cp36m-linux_x86_64.whl size=226415 sha256=a2be72d7017fa2550d72eb4e265014645744678480d3ef08e57c509b670c1cfa
#   Stored in directory: /root/.cache/pip/wheels/69/b4/26/9a673d2333de6af3865b5a2b462b3b0cfe4556ae69979434dd
# Successfully built tsne
# ...

# %%
from sklearn.manifold import TSNE

# %%
def tsne_plot(model):
    "Creates and TSNE model and plots it"
    labels = []
    tokens = []

    for word in model.wv.vocab:
        tokens.append(model[word])
        labels.append(word)
    
    tsne_model = TSNE(perplexity=40, n_components=2, init='pca', n_iter=2500, random_state=23)
    new_values = tsne_model.fit_transform(tokens)

    x = []
    y = []
    for value in new_values:
        x.append(value[0])
        y.append(value[1])
        
    plt.figure(figsize=(16, 16)) 
    for i in range(len(x)):
        plt.scatter(x[i],y[i])
        plt.annotate(labels[i],
                     xy=(x[i], y[i]),
                     xytext=(5, 2),
                     textcoords='offset points',
                      ha='right',
                     va='bottom')
    plt.show()

# %%
tsne_plot(model1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   import sys

# %% [markdown]
# # **Implementation a FastText Embedding model**

# %%
from gensim.models import FastText


model2 = FastText(all, min_count = 1, workers=cpu_count())

# %%
#say_vector = model2.wv['مجلة']  # get vector for word
model2['مجلة']
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([ 6.8119721e-04,  7.1363000e-04, -2.2632815e-03,  6.6555664e-04,
#         2.3908436e-03,  1.7106198e-04,  2.5879971e-03, -1.5313608e-03,
#        -1.3312272e-03, -6.2392798e-04, -8.8907557e-04,  7.3943305e-04,
#        -2.4658881e-04,  6.3681154e-04, -1.1011508e-03,  3.8859484e-04,
#        -8.8203512e-04,  2.1714149e-03,  3.0663484e-03, -5.2682147e-04,
#        -2.2889895e-03, -7.8335659e-05,  2.7082381e-03, -9.5385889e-04,
#         2.8413257e-03,  4.7685103e-03, -1.5502360e-03, -2.3588738e-03,
#         4.3814580e-04,  5.7487239e-05,  1.8758435e-03, -7.8100455e-04,
#         2.6581029e-03,  1.9333165e-03, -3.5805450e-04,  1.0498625e-03,
#         1.1812503e-03, -4.0376221e-04, -1.2498861e-03,  1.0739063e-03,
# ...

# %%
model2.most_similar('موسيقي')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('الموسيقار', 0.3403826951980591),
#  ('وكيف', 0.29017361998558044),
#  ('والمجلات', 0.27032899856567383),
#  ('تمثل', 0.27002689242362976),
#  ('تبعا', 0.22561603784561157),
#  ('أفضل', 0.19820374250411987),
#  ('ومتانة', 0.19513016939163208),
#  ('قرأ', 0.19247563183307648),
#  ('الجو', 0.19230465590953827),
#  ('والمتانة', 0.19182716310024261)]

# %% [markdown]
# # **BERT**

# %%
# !pip install bert-serving-server  # server
# !pip install bert-serving-client

# %%
# !bert-serving-start -model_dir /tmp/english_L-12_H-768_A-12/ -num_worker=4
# Out:
# usage: /usr/local/bin/bert-serving-start -model_dir /tmp/english_L-12_H-768_A-12/ -num_worker=4
#                  ARG   VALUE
# __________________________________________________
#            ckpt_name = bert_model.ckpt
#          config_name = bert_config.json
#                 cors = *
#                  cpu = False
#           device_map = []
#        do_lower_case = True
#   fixed_embed_length = False
#                 fp16 = False
#  gpu_memory_fraction = 0.5
#        graph_tmp_dir = None
#     http_max_connect = 10
#            http_port = None
#         mask_cls_sep = False
#       max_batch_size = 256
#          max_seq_len = 25
#            model_dir = /tmp/english_L-12_H-768_A-12/
# no_position_embeddings = False
#     no_special_token = False
#           num_worker = 4
#        pooling_layer = [-2]
#     pooling_strategy = REDUCE_MEAN
#                 port = 5555
#             port_out = 5556
#        prefetch_size = 10
#  priority_batch_size = 16
# ...

# %%
from bert_serving.client import BertClient

client = BertClient()
vectors = client.encode(["dog"],["cat"],["man"])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-314-1fa1b3574d1e> in <module>()
#       1 from bert_serving.client import BertClient
#       2
# ----> 3 client = BertClient()
#       4 vectors = client.encode(["dog"],["cat"],["man"])
#
# /usr/local/lib/python3.6/dist-packages/bert_serving/client/__init__.py in __init__(self, ip, port, port_out, output_fmt, show_server_config, identity, check_version, check_length, check_token_info, ignore_all_checks, timeout)
#     106
#     107         if not ignore_all_checks and (check_version or show_server_config or check_length or check_token_info):
# --> 108             s_status = self.server_config
#     109
#     110             if check_version and s_status['server_version'] != self.status['client_version']:
#
# /usr/local/lib/python3.6/dist-packages/bert_serving/client/__init__.py in arg_wrapper(self, *args, **kwargs)
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity
cos_lib = cosine_similarity(vectors[1,:],vectors[2,:]) #similarity between
#cat and dog

# %% [markdown]
# # **Step2 :test Collocation corpus **
